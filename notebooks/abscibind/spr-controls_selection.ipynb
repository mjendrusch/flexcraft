# %%
import pandas as pd

# %%
df = pd.read_csv("../..data/o1_iptm_scoring/spr-controls.csv")
df

# %%
pd.concat([(df[df["Binder"]].sample(frac=0.1)), df[~df["Binder"]].sample(frac=0.1)]).reset_index().to_csv("../../data/o1_iptm_scoring/spr-controls_selection.csv")
